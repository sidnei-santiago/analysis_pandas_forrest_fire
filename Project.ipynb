# %% [markdown]
# <h5>Forrest Amazon Fire</h5>

# %%
import pandas as pd

# %%
df = pd.read_csv("amazon.csv", encoding='latin1')

# %%
df.head()
# Out:
#    year state    month  number        date
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01
# 3  2001  Acre  Janeiro     0.0  2001-01-01
# 4  2002  Acre  Janeiro     0.0  2002-01-01

# %%
df.columns
# Out:
# Index(['year', 'state', 'month', 'number', 'date'], dtype='object')

# %%
df[["state", "number", "year"]]
# Out:
#           state  number  year
# 0          Acre     0.0  1998
# 1          Acre     0.0  1999
# 2          Acre     0.0  2000
# 3          Acre     0.0  2001
# 4          Acre     0.0  2002
# ...         ...     ...   ...
# 6449  Tocantins   128.0  2012
# 6450  Tocantins    85.0  2013
# 6451  Tocantins   223.0  2014
# 6452  Tocantins   373.0  2015
# 6453  Tocantins   119.0  2016
#
# [6454 rows x 3 columns]

# %%
df.iloc[1:7]
# Out:
#    year state    month  number        date
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01
# 3  2001  Acre  Janeiro     0.0  2001-01-01
# 4  2002  Acre  Janeiro     0.0  2002-01-01
# 5  2003  Acre  Janeiro    10.0  2003-01-01
# 6  2004  Acre  Janeiro     0.0  2004-01-01

# %%
for index, row in df.iterrows():
    print(index, row["state"])
# Out:
# 0 Acre
# 1 Acre
# 2 Acre
# 3 Acre
# 4 Acre
# 5 Acre
# 6 Acre
# 7 Acre
# 8 Acre
# 9 Acre
# 10 Acre
# 11 Acre
# 12 Acre
# 13 Acre
# 14 Acre
# 15 Acre
# 16 Acre
# 17 Acre
# 18 Acre
# 19 Acre
# 20 Acre
# 21 Acre
# 22 Acre
# 23 Acre
# 24 Acre
# 25 Acre
# 26 Acre
# 27 Acre
# 28 Acre
# 29 Acre
# 30 Acre
# 31 Acre
# 32 Acre
# 33 Acre
# 34 Acre
# 35 Acre
# 36 Acre
# 37 Acre
# 38 Acre
# 39 Acre
# 40 Acre
# 41 Acre
# 42 Acre
# 43 Acre
# 44 Acre
# 45 Acre
# 46 Acre
# 47 Acre
# 48 Acre
# 49 Acre
# 50 Acre
# 51 Acre
# 52 Acre
# 53 Acre
# 54 Acre
# 55 Acre
# 56 Acre
# 57 Acre
# 58 Acre
# 59 Acre
# 60 Acre
# 61 Acre
# 62 Acre
# 63 Acre
# 64 Acre
# 65 Acre
# 66 Acre
# 67 Acre
# 68 Acre
# 69 Acre
# 70 Acre
# 71 Acre
# 72 Acre
# 73 Acre
# 74 Acre
# 75 Acre
# 76 Acre
# 77 Acre
# 78 Acre
# 79 Acre
# 80 Acre
# 81 Acre
# 82 Acre
# 83 Acre
# 84 Acre
# 85 Acre
# 86 Acre
# 87 Acre
# 88 Acre
# 89 Acre
# 90 Acre
# 91 Acre
# 92 Acre
# 93 Acre
# 94 Acre
# 95 Acre
# 96 Acre
# 97 Acre
# 98 Acre
# 99 Acre
# ...

# %%
df.loc[df["year"] == 1999]
# Out:
#       year      state      month  number        date
# 1     1999       Acre    Janeiro   0.000  1999-01-01
# 21    1999       Acre  Fevereiro   0.000  1999-01-01
# 41    1999       Acre      Março   0.000  1999-01-01
# 61    1999       Acre      Abril   0.000  1999-01-01
# 81    1999       Acre       Maio   0.000  1999-01-01
# ...    ...        ...        ...     ...         ...
# 6356  1999  Tocantins     Agosto   1.284  1999-01-01
# 6376  1999  Tocantins   Setembro   3.415  1999-01-01
# 6396  1999  Tocantins    Outubro   1.378  1999-01-01
# 6416  1999  Tocantins   Novembro  29.000  1999-01-01
# 6436  1999  Tocantins   Dezembro  16.000  1999-01-01
#
# [324 rows x 5 columns]

# %%
df.describe()
# Out:
#               year       number
# count  6454.000000  6454.000000
# mean   2007.461729   108.293163
# std       5.746654   190.812242
# min    1998.000000     0.000000
# 25%    2002.000000     3.000000
# 50%    2007.000000    24.000000
# 75%    2012.000000   113.000000
# max    2017.000000   998.000000

# %%
df.sort_values(["state", "number"])
# Out:
#       year      state    month  number        date
# 0     1998       Acre  Janeiro     0.0  1998-01-01
# 1     1999       Acre  Janeiro     0.0  1999-01-01
# 2     2000       Acre  Janeiro     0.0  2000-01-01
# 3     2001       Acre  Janeiro     0.0  2001-01-01
# 4     2002       Acre  Janeiro     0.0  2002-01-01
# ...    ...        ...      ...     ...         ...
# 6330  2013  Tocantins    Junho   873.0  2013-01-01
# 6329  2012  Tocantins    Junho   922.0  2012-01-01
# 6339  2002  Tocantins    Julho   976.0  2002-01-01
# 6344  2007  Tocantins    Julho   982.0  2007-01-01
# 6346  2009  Tocantins    Julho   989.0  2009-01-01
#
# [6454 rows x 5 columns]

# %%
df_para = df.loc[df["state"] == "Pará"]

# %%
df_para
# Out:
#       year state     month   number        date
# 3108  1998  Pará   Janeiro    0.000  1998-01-01
# 3109  1999  Pará   Janeiro   87.000  1999-01-01
# 3110  2000  Pará   Janeiro   30.000  2000-01-01
# 3111  2001  Pará   Janeiro   34.000  2001-01-01
# 3112  2002  Pará   Janeiro  144.000  2002-01-01
# ...    ...   ...       ...      ...         ...
# 3342  2012  Pará  Dezembro    1.812  2012-01-01
# 3343  2013  Pará  Dezembro    5.514  2013-01-01
# 3344  2014  Pará  Dezembro    4.828  2014-01-01
# 3345  2015  Pará  Dezembro    6.610  2015-01-01
# 3346  2016  Pará  Dezembro    3.300  2016-01-01
#
# [239 rows x 5 columns]

# %%
df_para2 = df_para.loc[df_para["year"] == 2015]

# %%
df_para2
# Out:
#       year state      month   number        date
# 3125  2015  Pará    Janeiro  725.000  2015-01-01
# 3145  2015  Pará  Fevereiro  108.000  2015-01-01
# 3165  2015  Pará      Março   61.000  2015-01-01
# 3185  2015  Pará      Abril   27.000  2015-01-01
# 3205  2015  Pará       Maio   95.000  2015-01-01
# 3225  2015  Pará      Junho  265.000  2015-01-01
# 3245  2015  Pará      Julho  906.000  2015-01-01
# 3265  2015  Pará     Agosto    7.913  2015-01-01
# 3285  2015  Pará   Setembro   11.068  2015-01-01
# 3305  2015  Pará    Outubro    7.781  2015-01-01
# 3325  2015  Pará   Novembro    9.643  2015-01-01
# 3345  2015  Pará   Dezembro    6.610  2015-01-01

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(15,10))
plt.plot(df_para2["month"], df_para2["number"])
plt.xlabel('Meses de 2015 no Pará')
plt.show()

# %%
df.groupby("year", sort=False)["number"].count()
# Out:
# year
# 1998    324
# 1999    324
# 2000    324
# 2001    324
# 2002    324
# 2003    324
# 2004    324
# 2005    324
# 2006    324
# 2007    324
# 2008    324
# 2009    324
# 2010    324
# 2011    324
# 2012    324
# 2013    324
# 2014    324
# 2015    324
# 2016    324
# 2017    298
# Name: number, dtype: int64

# %%
by_state = df.groupby("state")

# %%
by_state

# %%
for state, frame in by_state:
    print(f"First 2 entries for {state!r}")
    print("------------------------")
    print(frame.head(2), end="\n\n")
# Out:
# First 2 entries for 'Acre'
# ------------------------
#    year state    month  number        date
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
#
# First 2 entries for 'Alagoas'
# ------------------------
#      year    state    month  number        date
# 239  1998  Alagoas  Janeiro     0.0  1998-01-01
# 240  1999  Alagoas  Janeiro    58.0  1999-01-01
#
# First 2 entries for 'Amapa'
# ------------------------
#      year  state    month  number        date
# 479  1998  Amapa  Janeiro     0.0  1998-01-01
# 480  1999  Amapa  Janeiro     0.0  1999-01-01
#
# First 2 entries for 'Amazonas'
# ------------------------
#      year     state    month  number        date
# 718  1998  Amazonas  Janeiro     0.0  1998-01-01
# 719  1999  Amazonas  Janeiro     3.0  1999-01-01
#
# First 2 entries for 'Bahia'
# ------------------------
#      year  state    month  number        date
# 957  1998  Bahia  Janeiro     0.0  1998-01-01
# ...

# %%
df_ba = df.loc[df["state"] == "Bahia"]

# %%
df_ba.groupby("year")["number"].sum()
# Out:
# year
# 1998    1224.687
# 1999    1197.582
# 2000    1378.635
# 2001    2427.651
# 2002    2280.700
# 2003    3076.150
# 2004    1644.409
# 2005    2358.066
# 2006    2509.085
# 2007    2210.279
# 2008    1912.703
# 2009    2185.162
# 2010    2515.010
# 2011    2025.047
# 2012    3454.937
# 2013    2571.650
# 2014    2457.367
# 2015    2355.058
# 2016    3520.234
# 2017    1441.814
# Name: number, dtype: float64
